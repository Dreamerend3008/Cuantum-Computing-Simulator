# %%
from services.custom_gate_service import get_custom_gate, save_custom_gate, delete_custom_gate
from shared.interfaces import CustomGateDef

# %%
custom_gate_dict = {
        "name": "MY_BELL_GATE_3",
        "num_qubits": 3,
        "instructions": [
            {"name": "H", "qubits": [0]},
            {"name": "CX", "qubits": [0, 1]},
            {"name": "CX", "qubits": [0, 2]}
        ]
}

# %%
custom_gate = CustomGateDef.from_dict(custom_gate_dict)

# %%
save_custom_gate(custom_gate)

# %%
custom_gate = get_custom_gate("MY_BELL_GATE_3")
print(custom_gate)
# Out:
# {'name': 'MY_BELL_GATE_3', 'num_qubits': 3, 'instructions': [{'name': 'H', 'qubits': [0]}, {'name': 'CX', 'qubits': [0, 1]}, {'name': 'CX', 'qubits': [0, 2]}]}

# %%
delete_custom_gate("MY_BELL_GATE_3")
